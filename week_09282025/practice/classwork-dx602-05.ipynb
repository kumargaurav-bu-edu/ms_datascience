# %%
import math

import matplotlib.pyplot as plt

# %%
q1r = [i / 120 for i in range(20, 120)]
q5x = [math.cos(i / 10) * q1r[i] for i in range(100)]
q5y = [math.sin(i / 10) * q1r[i] for i in range(100)]

# %%
plt.plot(q5x, q5y, label="mystery #1")
plt.xlabel("mystery #2")
plt.ylabel("mystery #3")
plt.title("mystery #4")
# Out:
# Text(0.5, 1.0, 'mystery #4')
