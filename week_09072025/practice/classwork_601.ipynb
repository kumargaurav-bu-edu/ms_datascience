# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
q4 = [97, 62, 52, 41, 83, 61, 50, 42, 20, 56, 23, 91, 73, 82, 11, 73, 32, 51, 88, 68, 73, 44, 74, 71, 80, 47, 8, 60, 89, 91, 33, 42, 25, 58, 62, 37, 57, 11, 5, 75, 61, 9, 37, 31, 46, 75, 44, 11, 0, 59, 3, 66, 91, 81, 22, 20, 10, 31, 38, 45, 9, 29, 80, 11, 13, 15, 15, 98, 81, 59, 25, 98, 86, 56, 77, 38, 94, 26, 66, 32, 13, 6, 65, 20, 30, 36, 10, 82, 74, 51, 35, 50, 4, 25, 62, 89, 43, 78, 31, 79]

# %%
# variance
np.var(q4)
# Out:
# 765.7339

# %%
# sample variance
np.var(q4, ddof=1)
# Out:
# 773.4685858585858

# %%
x = {6,23,5,2,4}
mean = np.mean(list(x))
print(mean)
# Out:
# 8.0

# %%
X = {42,42,42,42,42}
data = list(X)
var = np.var(data)
print(var)
# Out:
# 0.0

# %%
X = {1,2,1,3,4,7,6,5}
per = np.percentile(list(X), 75)
print(per)
# Out:
# 5.5

# %%
X = {1,2,1,3,4,5,6,7}
values, counts = np.unique(list(X), return_counts=True)
index = np.argmax(counts)
mode_value = values[index]
print("Mode: ", mode_value)
# Out:
# Mode:  1
