# %%
def p11(n):
    fact = 1
    if(n<=1):
        return 1
    for i in range(1,n):
        fact = fact + fact * i
    return fact

# %%
p11(4)
# Out:
# 24

# %%
def p12(dictionaries, key):
    #for d in dictionaries:
    #    print(d[key])
    # print(v for v in dictionaries[key] )
    return list({ele[key] for ele in dictionaries})

# %%
f12 = [
  {'score': 9},
  {'score': 9},
  {'score': 7},
  {'score': 6},
  {'score': 5}
]
p12(f12, "score")
# Out:
# [9, 5, 6, 7]

# %%
# YOUR CHANGES HERE

def p13(dictionaries, key):
    return [ele for ele in dictionaries if not ele[key]]

# %%
f12 = [
  {'score': 9},
  {'score': None},
  {'score': 7},
  {'score': 6},
  {'score': 5}
]
p13(f12, "score")
# Out:
# [{'score': None}]

# %%
def f(x):
    x = x * 3
    return x

def g(y):
    f(y)
    return y

x = 4
f(x)
g(x)
print(x)
# Out:
# 4

# %%
def f(x):
    def g(y):
        def h(x):
            return x + y

        return h(x)

    x = g(2)
    return g(3)

print(f(5))
# Out:
# 10

# %%
d = {"a": "b", "c": 3, "d": 3}
for k in d:
    print(k, d[k])
# Out:
# a b
# c 3
# d 3

# %%
s = {1, 1, 2, 2, 3, 3, 3, 3, 3, 4, 4, 4, 5}
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
def p19(seq):
    return any(0.5 <= x <= 0.75 for x in seq )

print(p19([0.5, 0.6]))
# Out:
# True

# %%
x = 7
y = 4
for z in range(y):
    if z:
        x = x * z
        print(x)
p20 =x
print(p20)
# Out:
# 7
# 14
# 42
# 42

# %%
# Write a function p3 that takes in a sequence, and returns a list of the values that 
# are both not None and considered false by Python.
def p3(seq):
    return [x for x in seq if (x is not None and not x)]
