# %% [markdown]
# - Azure setup
#
# https://microsoftlearning.github.io/mslearn-synapse/Instructions/Labs/01-Explore-Azure-Synapse.html
#
# - SQL Practice
#
# https://datalemur.com/sql-tutorial
#
# - Setting budget alert
#
# https://www.youtube.com/watch?v=UrkHiUx19Po
