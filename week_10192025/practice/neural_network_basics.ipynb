# %%
import numpy as np

# %%
def sigmoid(x):
    # Sigmoid activation function f(x) = 1 / (1 + e^(-x))
    return 1 / (1 + np.exp(-x))

# %%
class Neuron:
    def __init__(self, weights, bias):
        self.weights = weights
        self.bias = bias
    
    def feedforward(self, inputs):
        # Weight inputs, add bias, then use the activation function
        total = np.dot(self.weights, inputs) + self.bias
        return sigmoid(total)

# %%
weights = np.array([0, 1]) # weights for the two inputs w1=0 and w2=1
bias = 4    # bias = 4
n = Neuron(weights, bias)

x = np.array([2, 3]) # inputs x1=2 and x2=3
print(n.feedforward(x))
# Out:
# 0.9990889488055994

# %%
class OurNeuralNetwork:
  '''
  A neural network with:
    - 2 inputs
    - a hidden layer with 2 neurons (h1, h2)
    - an output layer with 1 neuron (o1)
  Each neuron has the same weights and bias:
    - w = [0, 1]
    - b = 0
  '''
  def __init__(self) -> None:
    weights = np.array([0, 1])
    bias = 0

    # The Neuron class is here from previous section
    self.h1 = Neuron(weights, bias)
    self.h2 = Neuron(weights, bias)
    self.o1 = Neuron(weights, bias)

  def feedforward(self, inputs):
    # Do a feedforward
    out_h1 = self.h1.feedforward(inputs)
    out_h2 = self.h2.feedforward(inputs)
    # Then do a feedforward of our outputs, 
    # together with the outputs (h1 and h2) of hidden neurons
    return self.o1.feedforward(np.array([out_h1, out_h2]))

# %%
network = OurNeuralNetwork()
x = np.array([2, 3])
print(network.feedforward(x))
# Out:
# 0.7216325609518421

# %%
def mse_loss(y_true, y_pred):
    # Convert to numpy arrays if they aren't already
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    return ((y_true - y_pred) ** 2).mean()


y_true = [1, 0, 0, 1]
y_pred = [0, 0, 0, 0]

print(mse_loss(y_true, y_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       5 y_true = [1, 0, 0, 1]
#       6 y_pred = [0, 0, 0, 0]
# ----> 8 print(mse_loss(y_true, y_pred))
#
# Cell In[9], line 2, in mse_loss(y_true, y_pred)
#       1 def mse_loss(y_true, y_pred):
# ----> 2     return ((y_true - y_pred) ** 2).mean()
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
