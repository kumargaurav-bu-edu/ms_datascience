# %% [markdown]
# ## Important urls
#
# - Azure cheetsheet
#  https://github.com/milanm/azure-cheat-sheet?tab=readme-ov-file
#
# - Intermediate SQL for Data Scientists
#  https://www.linkedin.com/learning/intermediate-sql-for-data-scientists-25322592
#
# - SQL Essential Training
#  https://www.linkedin.com/learning/sql-essential-training-20685933
#
# - SQL interview
#   https://datalemur.com/sql-tutorial18
#
# - Explore Azure Synapsis
#  https://microsoftlearning.github.io/mslearn-synapse/Instructions/Labs/01-Explore-Azure-Synapse.html

# %% [markdown]
# - To create resource factory
#     az deployment group create --resource-group kgomdsuserg --template-file ./template/template.json --parameters ./template/parameters.json
#
# - Set default Subscription
#     az account set --subscription "0f8274ab-528c-4f39-adec-0ec8e718e4e8"
